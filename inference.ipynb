# %% [markdown]
# # Dr. Stone Character Classifier
#
# This app can recognize the following characters from the amazing Dr. Stone anime: Senku, Kohaku, Tsukasa, Chrome, Suika, and Gen. Upload a picture of one of them to check it out!

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

path = Path()
learn_inf = load_learner(path/'model.pkl')

# %%
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
out_pl.clear_output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(224,224))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Upload a picture!'), btn_upload, btn_run, out_pl, lbl_pred])
